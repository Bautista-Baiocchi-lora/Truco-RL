# %%
from player import Player
from dealer import Dealer
from game import TrucoGame
from environment import TrucoEnvironment
from agent import Agent, save_agent, load_agent
from actions import game_actions, game_actions_list
import random
import itertools
import torch as T
import numpy as np
import logging

# %%
device = T.device("cuda:0" if T.cuda.is_available() else "cpu")

# %%
num_players = 6
ids = list(range(0,num_players))
#names = ['John', 'Holie', 'Alice', 'Bob', 'Chris', 'Kevin']
#names = ['Miss Lu', 'Bauti', 'Jamon', 'Frank', 'Hitler', 'Anne']
names = ['Ares', 'Athena', 'Zeus', 'Dionysus', 'Hades', 'Eros']


players = [Player(id) for id in names]
agents = [Agent(player=players[i], state_space_dim=339, action_space_dim=game_actions.shape[0],model_type='deep', device=device, replay_buffer_size=10000 + 3000*i, batch_size=48, target_update_freq=1500, epsilon_end=0.05, epsilon_decay=1000000, learning_rate=0.001) for i in range(6)]
#agents = [load_agent(name, device) for name in names]

random.shuffle(agents)

envs = [TrucoEnvironment([a1.player, a2.player], logging_level=logging.WARNING) for a1, a2 in zip(agents[0::2], agents[1::2])]

# %%
def get_env_by_agent(envs, agent):
    for env in envs:
        if agent.player in env.players:
            return env
    return None

def get_agents_by_env(agents, env):
    playing = []
    for agent in agents:
        if agent.player in env.players:
            playing.append(agent)
    return playing[0], playing[1]

# %%
for env in envs:
    
    playing_agents = get_agents_by_env(agents, env)
    
    for agent in playing_agents:

        # reset env
        starting_player, legal_actions, game_state = env.reset(False)

        # Initialize the ReplayBuffer
        while len(agent.replay_buffer) < agent.min_replay_size:
            # pick legal action given uniform distribution
            action = np.random.choice(legal_actions, 1, [1/len(legal_actions) for i in legal_actions])
            action = game_actions_list.index(action)

            # Take action, observer outcome
            rew, done, next_player, next_legal_actions, new_game_state = env.step(starting_player, action)

            #Save transition for training later
            transition = (game_state, action, rew, done, new_game_state)
            agent.save_transition(transition)

            starting_player = next_player
            legal_actions = next_legal_actions
            game_state = new_game_state

            if done:
                starting_player, legal_actions, game_state = env.reset()

# %%
PLAYER_SWAP_FREQ=35000

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from timeit import default_timer as timer
import datetime

for epoch in itertools.count():
    print(f"Starting epoch: {epoch}")
    epoch_start = timer()
    
    for env in envs:
        
        env_start = timer()

        starting_player, legal_actions, game_state = env.reset(False)
        playing_agents = get_agents_by_env(agents, env)

        # Main training loop
        for step in itertools.count():
            agent = [agent for agent in playing_agents if agent.player == starting_player][0]

            action = agent.choose_action(legal_actions, game_state)

            # Take action, observe outcome
            rew, done, next_player, next_legal_actions, new_game_state = env.step(agent.player, action)

            #Save transition for training later
            transition = (game_state, action, rew, done, new_game_state)
            agent.save_transition(transition)

            starting_player = next_player
            legal_actions = next_legal_actions
            game_state = new_game_state

            if done:
                # Give agents their episode reward
                for agent in playing_agents:
                    agent.save_reward(env.game.get_score(agent.player))

                starting_player, legal_actions, game_state = env.reset(False)

            # Learn from replay buffer
            agent.learn()

            # Logging
            if step % 15000 == 0 and step > 0:
                for agent in playing_agents:
                    avg_reward = np.mean(agent.reward_buffer)
                    print(f"Step: {step} | Player: {agent.player.get_id()} | Avg reward: {avg_reward} | W/L: {max([w if p == agent.player else 0 for p, w in env.games_won])/env.games_played} | Games: {env.games_played} | Time: {str(datetime.timedelta(seconds=(timer() - env_start)))}")   

            # Break out of training loop when swap rate is reached
            if step % PLAYER_SWAP_FREQ == 0 and step > 0:
                print(f"Player {playing_agents[0].player.get_id()} vs Player {playing_agents[1].player.get_id()} finished.")
                
                # Clear GPU cache
                T.cuda.empty_cache()
                break;

    
                
    # Destroy all envs
    envs.clear()

    random.shuffle(agents)

    # Create new Envs
    envs = [TrucoEnvironment([a1.player, a2.player]) for a1, a2 in zip(agents[0::2], agents[1::2])]
    
    # Save models
    if epoch % 2 == 0 and epoch > 0:
        for agent in agents:
            save_agent(agent)
    
    print(f"Epoch {epoch} finished in {str(datetime.timedelta(seconds=(timer() - epoch_start)))}")
# Out:
# Starting epoch: 0
# Step: 15000 | Player: Hades | Avg reward: 0.99 | W/L: 0.5270828801392212 | Games: 4597 | Time: 0:00:42.464832
# Step: 15000 | Player: Athena | Avg reward: 1.06 | W/L: 0.4729171198607788 | Games: 4597 | Time: 0:00:42.465013
# Step: 30000 | Player: Hades | Avg reward: 0.96 | W/L: 0.5275608903391213 | Games: 8581 | Time: 0:01:24.977836
# Step: 30000 | Player: Athena | Avg reward: 0.93 | W/L: 0.4724391096608787 | Games: 8581 | Time: 0:01:24.978027
# Player Hades vs Player Athena finished.
# Step: 15000 | Player: Eros | Avg reward: 0.96 | W/L: 0.5364368066130085 | Games: 4597 | Time: 0:00:41.337760
# Step: 15000 | Player: Ares | Avg reward: 1.12 | W/L: 0.46356319338699153 | Games: 4597 | Time: 0:00:41.337930
# Step: 30000 | Player: Eros | Avg reward: 1.1 | W/L: 0.5345552183049265 | Games: 8566 | Time: 0:01:23.405233
# Step: 30000 | Player: Ares | Avg reward: 1.09 | W/L: 0.46544478169507353 | Games: 8566 | Time: 0:01:23.405366
# Player Eros vs Player Ares finished.
# Step: 15000 | Player: Dionysus | Avg reward: 1.05 | W/L: 0.5196746537700594 | Games: 4549 | Time: 0:00:41.898448
# Step: 15000 | Player: Zeus | Avg reward: 0.82 | W/L: 0.48032534622994066 | Games: 4549 | Time: 0:00:41.898620
# Step: 30000 | Player: Dionysus | Avg reward: 0.82 | W/L: 0.5213744903902154 | Games: 8585 | Time: 0:01:23.485620
# Step: 30000 | Player: Zeus | Avg reward: 1.07 | W/L: 0.4786255096097845 | Games: 8585 | Time: 0:01:23.485795
# Player Dionysus vs Player Zeus finished.
# Epoch 0 finished in 0:04:53.708576
# Starting epoch: 1
# Step: 15000 | Player: Dionysus | Avg reward: 1.16 | W/L: 0.5324740965377811 | Games: 3957 | Time: 0:00:42.266409
# Step: 15000 | Player: Eros | Avg reward: 0.74 | W/L: 0.46752590346221884 | Games: 3957 | Time: 0:00:42.266591
# Step: 30000 | Player: Dionysus | Avg reward: 0.91 | W/L: 0.5202523659305993 | Games: 7925 | Time: 0:01:24.509495
# Step: 15000 | Player: Zeus | Avg reward: 0.99 | W/L: 0.5084690553745929 | Games: 3070 | Time: 0:00:44.133821
# Step: 15000 | Player: Ares | Avg reward: 0.98 | W/L: 0.49153094462540714 | Games: 3070 | Time: 0:00:44.134006
# Step: 30000 | Player: Zeus | Avg reward: 1.23 | W/L: 0.5180958591457451 | Games: 6134 | Time: 0:01:28.502987
# Step: 30000 | Player: Ares | Avg reward: 0.82 | W/L: 0.481904140854255 | Games: 6134 | Time: 0:01:28.503156
# Player Zeus vs Player Ares finished.
# Model Dionysus saved.
# Model Ares saved.
# Model Hades saved.
# Model Eros saved.
# Model Zeus saved.
# Model Athena saved.
# Epoch 14 finished in 0:05:10.930802
# Starting epoch: 15
# Step: 15000 | Player: Dionysus | Avg reward: 1.16 | W/L: 0.5207022192779066 | Games: 3019 | Time: 0:00:44.318317
# Step: 15000 | Player: Ares | Avg reward: 0.94 | W/L: 0.4792977807220934 | Games: 3019 | Time: 0:00:44.318498
# Step: 30000 | Player: Dionysus | Avg reward: 0.93 | W/L: 0.5356605979622515 | Games: 5987 | Time: 0:01:28.455083
# Step: 30000 | Player: Ares | Avg reward: 0.91 | W/L: 0.4643394020377484 | Games: 5987 | Time: 0:01:28.455253
# Player Dionysus vs Player Ares finished.
# Step: 15000 | Player: Hades | Avg reward: 0.79 | W/L: 0.512042230287034 | Games: 3031 | Time: 0:00:44.419566
# Step: 15000 | Player: Eros | Avg reward: 1.19 | W/L: 0.487957769712966 | Games: 3031 | Time: 0:00:44.419718
# Step: 30000 | Player: Hades | Avg reward: 1.02 | W/L: 0.5208611481975968 | Games: 5992 | Time: 0:01:29.035916
# Step: 30000 | Player: Eros | Avg reward: 1.09 | W/L: 0.47913885180240323 | Games: 5992 | Time: 0:01:29.036129
# Player Hades vs Player Eros finished.
# Step: 15000 | Player: Zeus | Avg reward: 1.12 | W/L: 0.5289878807730102 | Games: 3053 | Time: 0:00:43.789455
# Step: 15000 | Player: Athena | Avg reward: 1.03 | W/L: 0.4710121192269898 | Games: 3053 | Time: 0:00:43.789621
# Step: 30000 | Player: Zeus | Avg reward: 1.11 | W/L: 0.5287625418060201 | Games: 5980 | Time: 0:01:28.625730
# Step: 30000 | Player: Athena | Avg reward: 0.91 | W/L: 0.47123745819397994 | Games: 5980 | Time: 0:01:28.625870
# Player Zeus vs Player Athena finished.
# Epoch 15 finished in 0:05:10.470774
# Starting epoch: 16
# Step: 15000 | Player: Athena | Avg reward: 1.06 | W/L: 0.5266757865937073 | Games: 2924 | Time: 0:00:44.523567
# Step: 15000 | Player: Zeus | Avg reward: 1.06 | W/L: 0.47332421340629277 | Games: 2924 | Time: 0:00:44.523750
# Step: 30000 | Player: Athena | Avg reward: 0.75 | W/L: 0.5204151071793127 | Games: 5878 | Time: 0:01:29.307547
# Step: 30000 | Player: Zeus | Avg reward: 1.15 | W/L: 0.47958489282068734 | Games: 5878 | Time: 0:01:29.307759
# Player Athena vs Player Zeus finished.
# Step: 15000 | Player: Dionysus | Avg reward: 1.32 | W/L: 0.5212912087912088 | Games: 2912 | Time: 0:00:44.361923
# Step: 15000 | Player: Eros | Avg reward: 1.02 | W/L: 0.47870879120879123 | Games: 2912 | Time: 0:00:44.362100
# Step: 30000 | Player: Dionysus | Avg reward: 1.06 | W/L: 0.525085910652921 | Games: 5820 | Time: 0:01:29.134716
# Step: 30000 | Player: Eros | Avg reward: 0.99 | W/L: 0.474914089347079 | Games: 5820 | Time: 0:01:29.134884
# Player Dionysus vs Player Eros finished.
# Step: 15000 | Player: Ares | Avg reward: 1.03 | W/L: 0.5348284063880394 | Games: 2943 | Time: 0:00:44.425444
# Step: 15000 | Player: Hades | Avg reward: 1.1 | W/L: 0.4651715936119606 | Games: 2943 | Time: 0:00:44.425583
# Step: 30000 | Player: Ares | Avg reward: 1.16 | W/L: 0.53880418022957 | Games: 5837 | Time: 0:01:28.367817
# Step: 30000 | Player: Hades | Avg reward: 0.95 | W/L: 0.46119581977043 | Games: 5837 | Time: 0:01:28.367996
# Player Ares vs Player Hades finished.
# Model Hades saved.
# Model Ares saved.
# Model Eros saved.
# Model Zeus saved.
# Model Athena saved.
# Model Dionysus saved.
# Epoch 16 finished in 0:05:11.368834
# Starting epoch: 17
# Step: 15000 | Player: Hades | Avg reward: 0.86 | W/L: 0.5292107960368978 | Games: 2927 | Time: 0:00:44.635366
# Step: 15000 | Player: Ares | Avg reward: 1.13 | W/L: 0.47078920396310214 | Games: 2927 | Time: 0:00:44.635496
# Step: 30000 | Player: Hades | Avg reward: 1.01 | W/L: 0.5264069264069264 | Games: 5775 | Time: 0:01:29.622941
# Step: 30000 | Player: Ares | Avg reward: 1.22 | W/L: 0.47359307359307357 | Games: 5775 | Time: 0:01:29.623122
# Player Hades vs Player Ares finished.
# Step: 15000 | Player: Eros | Avg reward: 1.1 | W/L: 0.5149078726968174 | Games: 2985 | Time: 0:00:44.280281
# Step: 15000 | Player: Zeus | Avg reward: 1.09 | W/L: 0.4850921273031826 | Games: 2985 | Time: 0:00:44.280466
# Step: 30000 | Player: Eros | Avg reward: 1.02 | W/L: 0.5188679245283019 | Games: 5830 | Time: 0:01:28.805412
# Step: 30000 | Player: Zeus | Avg reward: 1.04 | W/L: 0.4811320754716981 | Games: 5830 | Time: 0:01:28.805544
# Player Eros vs Player Zeus finished.
# Step: 15000 | Player: Athena | Avg reward: 1.0 | W/L: 0.5352900069881202 | Games: 2862 | Time: 0:00:44.598644
# Step: 15000 | Player: Dionysus | Avg reward: 0.96 | W/L: 0.4647099930118798 | Games: 2862 | Time: 0:00:44.598838
# Step: 30000 | Player: Athena | Avg reward: 0.98 | W/L: 0.5217315412812009 | Games: 5729 | Time: 0:01:29.231591
# Step: 30000 | Player: Dionysus | Avg reward: 1.11 | W/L: 0.4782684587187991 | Games: 5729 | Time: 0:01:29.231759
# Player Athena vs Player Dionysus finished.
# Epoch 17 finished in 0:05:12.338091
# Starting epoch: 18
# Step: 15000 | Player: Hades | Avg reward: 0.86 | W/L: 0.5231530576175327 | Games: 2829 | Time: 0:00:44.720279
# Step: 15000 | Player: Zeus | Avg reward: 1.11 | W/L: 0.4768469423824673 | Games: 2829 | Time: 0:00:44.720429
# Step: 30000 | Player: Hades | Avg reward: 0.99 | W/L: 0.5297364672364673 | Games: 5616 | Time: 0:01:29.648113
# Step: 30000 | Player: Zeus | Avg reward: 0.87 | W/L: 0.4702635327635328 | Games: 5616 | Time: 0:01:29.648282
# Player Hades vs Player Zeus finished.
# Step: 15000 | Player: Dionysus | Avg reward: 1.02 | W/L: 0.5279061500177746 | Games: 2813 | Time: 0:00:45.041559
# Step: 15000 | Player: Eros | Avg reward: 1.07 | W/L: 0.47209384998222537 | Games: 2813 | Time: 0:00:45.041734
# Step: 30000 | Player: Dionysus | Avg reward: 0.87 | W/L: 0.5306230200633579 | Games: 5682 | Time: 0:01:29.620153
# Step: 30000 | Player: Eros | Avg reward: 0.98 | W/L: 0.469376979936642 | Games: 5682 | Time: 0:01:29.620329
# Player Dionysus vs Player Eros finished.
# Step: 15000 | Player: Athena | Avg reward: 0.92 | W/L: 0.5228734810578985 | Games: 2798 | Time: 0:00:45.012029
# Step: 15000 | Player: Ares | Avg reward: 1.01 | W/L: 0.4771265189421015 | Games: 2798 | Time: 0:00:45.012209
# Step: 30000 | Player: Athena | Avg reward: 0.86 | W/L: 0.5225048923679061 | Games: 5621 | Time: 0:01:30.006717
# Step: 30000 | Player: Ares | Avg reward: 1.04 | W/L: 0.4774951076320939 | Games: 5621 | Time: 0:01:30.006922
# Player Athena vs Player Ares finished.
# Model Zeus saved.
# Model Dionysus saved.
# Model Ares saved.
# Model Athena saved.
# Model Hades saved.
# Model Eros saved.
# Epoch 18 finished in 0:05:14.653713
# Starting epoch: 19
# Step: 15000 | Player: Zeus | Avg reward: 0.9 | W/L: 0.5310049893086244 | Games: 2806 | Time: 0:00:44.945409
# Step: 15000 | Player: Dionysus | Avg reward: 1.21 | W/L: 0.4689950106913756 | Games: 2806 | Time: 0:00:44.945587
# Step: 30000 | Player: Zeus | Avg reward: 1.04 | W/L: 0.5265822784810127 | Games: 5530 | Time: 0:01:30.332076
# Step: 30000 | Player: Dionysus | Avg reward: 0.79 | W/L: 0.47341772151898737 | Games: 5530 | Time: 0:01:30.332208
# Player Zeus vs Player Dionysus finished.
# Step: 15000 | Player: Ares | Avg reward: 1.19 | W/L: 0.5283700758944705 | Games: 2767 | Time: 0:00:44.866656
# Step: 15000 | Player: Athena | Avg reward: 1.1 | W/L: 0.47162992410552945 | Games: 2767 | Time: 0:00:44.866816
# Step: 30000 | Player: Ares | Avg reward: 1.01 | W/L: 0.5346355579670826 | Games: 5529 | Time: 0:01:29.956782
# Step: 30000 | Player: Athena | Avg reward: 0.87 | W/L: 0.4653644420329173 | Games: 5529 | Time: 0:01:29.956955
# Player Ares vs Player Athena finished.

# %%
for agent in agents:
    save_agent(agent)
