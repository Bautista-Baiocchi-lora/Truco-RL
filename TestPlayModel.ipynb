# %%
from player import Player
from dealer import Dealer
from game import TrucoGame
from environment import TrucoEnvironment
from agent import Agent, save_agent, load_agent
from actions import game_actions, game_actions_list
import random
import itertools
import torch as T
import numpy as np

# %%
device = T.device("cuda:0" if T.cuda.is_available() else "cpu")

# %%
num_players = 6
ids = list(range(0,num_players))
names = ['John', 'Holie', 'Alice', 'Bob', 'Chris', 'Kevin']
# other_names = ['Miss Lu', 'Bauti', 'Jamon', 'Frank', 'Hitler', 'Anne']
# god_names = ['Ares', 'Athena', 'Zeus', 'Dionysus', 'Hades', 'Eros']


#players = [Player(id) for id in names]
#agents = [Agent(player=players[i], state_space_dim=339, action_space_dim=game_actions.shape[0],model_type='shallow', device=device, replay_buffer_size=15000 + 10000*i, batch_size=64, target_update_freq=1500, epsilon_end=0.05, epsilon_decay=1000000, learning_rate=0.001) for i in range(6)]
agents = [load_agent(name, device) for name in names]

random.shuffle(agents)

envs = [TrucoEnvironment([a1.player, a2.player]) for a1, a2 in zip(agents[0::2], agents[1::2])]

# %%
def get_env_by_agent(envs, agent):
    for env in envs:
        if agent.player in env.players:
            return env
    return None

def get_agents_by_env(agents, env):
    playing = []
    for agent in agents:
        if agent.player in env.players:
            playing.append(agent)
    return playing[0], playing[1]

# %%
for env in envs:
    
    playing_agents = get_agents_by_env(agents, env)
    
    for agent in playing_agents:

        # reset env
        starting_player, legal_actions, game_state = env.reset(False)

        # Initialize the ReplayBuffer
        while len(agent.replay_buffer) < 80:
            # pick legal action given uniform distribution
            action = np.random.choice(legal_actions, 1, [1/len(legal_actions) for i in legal_actions])
            action = game_actions_list.index(action)

            # Take action, observer outcome
            rew, done, next_player, next_legal_actions, new_game_state = env.step(starting_player, action)

            #Save transition for training later
            transition = (game_state, action, rew, done, new_game_state)
            agent.save_transition(transition)

            starting_player = next_player
            legal_actions = next_legal_actions
            game_state = new_game_state

            if done:
                starting_player, legal_actions, game_state = env.reset()

# %%
PLAYER_SWAP_FREQ=50000

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from timeit import default_timer as timer
import datetime

for epoch in itertools.count():
    print(f"Starting epoch: {epoch}")
    epoch_start = timer()
    
    for env in envs:
        
        env_start = timer()

        starting_player, legal_actions, game_state = env.reset(False, goes_first=1)
        playing_agents = get_agents_by_env(agents, env)

        # Main training loop
        for step in itertools.count():
            agent = [agent for agent in playing_agents if agent.player == starting_player][0]

            action = agent.choose_action(legal_actions, game_state)

            # Take action, observe outcome
            rew, done, next_player, next_legal_actions, new_game_state = env.step(agent.player, action)

            #Save transition for training later
            transition = (game_state, action, rew, done, new_game_state)
            agent.save_transition(transition)

            starting_player = next_player
            legal_actions = next_legal_actions
            game_state = new_game_state

            if done:
                # Give agents their episode reward
                for agent in playing_agents:
                    agent.save_reward(env.game.get_score(agent.player))

                starting_player, legal_actions, game_state = env.reset(False)

            # Learn from replay buffer
            agent.learn()

            # Logging
            if step % 25000 == 0 and step > 0:
                for agent in playing_agents:
                    avg_reward = np.mean(agent.reward_buffer)
                    print(f"Step: {step} | Player: {agent.player.get_id()} | Avg reward: {avg_reward} | W/L: {max([w if p == agent.player else 0 for p, w in env.games_won])/env.games_played} | Games: {env.games_played} | Time: {str(datetime.timedelta(seconds=(timer() - env_start)))}")   

            # Break out of training loop when swap rate is reached
            if step % PLAYER_SWAP_FREQ == 0 and step > 0:
                print(f"Player {playing_agents[0].player.get_id()} vs Player {playing_agents[1].player.get_id()} finished.")
                
                # Clear GPU cache
                T.cuda.empty_cache()
                break;

    
                
    # Destroy all envs
    envs.clear()

    random.shuffle(agents)

    # Create new Envs
    envs = [TrucoEnvironment([a1.player, a2.player]) for a1, a2 in zip(agents[0::2], agents[1::2])]
    
    # Save models
    if epoch % 2 == 0 and epoch > 0:
        for agent in agents:
            save_agent(agent)
    
    print(f"Epoch {epoch} finished in {str(datetime.timedelta(seconds=(timer() - epoch_start)))}")
# Out:
# 07-Oct-21 10:49:31 - INFO - New Game.
# Starting epoch: 0
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['O4', 'B3', 'C2'] called real envido.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C10', 'E5', 'E12'] folded.
# 07-Oct-21 10:49:32 - INFO - Hand finished.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C10', 'E5', 'E12'] scored 0
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['O4', 'B3', 'C2'] scored 2
# 07-Oct-21 10:49:32 - INFO - New Game.
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['E10', 'O2', 'O4'] called envido.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['E7', 'O5', 'B3'] folded.
# 07-Oct-21 10:49:32 - INFO - Hand finished.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['E7', 'O5', 'B3'] scored 0
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['E10', 'O2', 'O4'] scored 2
# 07-Oct-21 10:49:32 - INFO - New Game.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C10', 'B3'] played O10
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['C3', 'O5', 'E3'] called real envido.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C10', 'B3'] called quiero envido
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['C3', 'O5', 'E3'] called truco to start truco
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C10', 'B3'] called re-truco
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['C3', 'O5', 'E3'] called quiero truco
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['O5', 'E3'] played C3
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['O5'] played E3
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['B3'] played C10
# 07-Oct-21 10:49:32 - INFO - Hand finished.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['B3'] scored 0
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['O5'] scored 6
# 07-Oct-21 10:49:32 - INFO - New Game.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['B12', 'C12', 'E2'] called envido.
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['E6', 'B1', 'C1'] folded.
# 07-Oct-21 10:49:32 - INFO - Hand finished.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['B12', 'C12', 'E2'] scored 2
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['E6', 'B1', 'C1'] scored 0
# 07-Oct-21 10:49:32 - INFO - New Game.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['E7', 'E11', 'B10'] called real envido.
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['B1', 'E2', 'O4'] folded.
# 07-Oct-21 10:49:32 - INFO - Hand finished.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['E7', 'E11', 'B10'] scored 2
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['B1', 'E2', 'O4'] scored 0
# 07-Oct-21 10:49:32 - INFO - New Game.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C3', 'B4'] played C11
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['C5', 'E3', 'O1'] called real envido.
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C3', 'B4'] called no quiero envido
# 07-Oct-21 10:49:32 - INFO - Player John | Cards: ['E3', 'O1'] played C5
# 07-Oct-21 10:49:32 - INFO - Player Bob | Cards: ['C3', 'B4'] called truco to start truco
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['E3', 'O1'] folded.
# 07-Oct-21 10:49:33 - INFO - Hand finished.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['C3', 'B4'] scored 1
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['E3', 'O1'] scored 1
# 07-Oct-21 10:49:33 - INFO - New Game.
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['E1', 'O3'] played O11
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['E10', 'B11'] played B3
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['E10'] played B11
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['E1'] played O3
# 07-Oct-21 10:49:33 - INFO - Hand finished.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['E10'] scored 1
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['E1'] scored 0
# 07-Oct-21 10:49:33 - INFO - New Game.
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['B6', 'O5', 'E6'] called envido.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['C4', 'E2', 'O1'] called quiero envido
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['B6', 'O5', 'E6'] called truco to start truco
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['C4', 'E2', 'O1'] called no quiero truco
# 07-Oct-21 10:49:33 - INFO - Hand finished.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['C4', 'E2', 'O1'] scored 0
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['B6', 'O5', 'E6'] scored 3
# 07-Oct-21 10:49:33 - INFO - New Game.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['B6', 'B10', 'C2'] called truco to start truco
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['O5', 'E3', 'E1'] called no quiero truco
# 07-Oct-21 10:49:33 - INFO - Hand finished.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['B6', 'B10', 'C2'] scored 1
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['O5', 'E3', 'E1'] scored 0
# 07-Oct-21 10:49:33 - INFO - New Game.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['B10', 'B3', 'B7'] called real envido.
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['C3', 'C12', 'C1'] called quiero envido
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['B3', 'B7'] played B10
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['C3', 'C12', 'C1'] folded.
# 07-Oct-21 10:49:33 - INFO - Hand finished.
# 07-Oct-21 10:49:33 - INFO - Player Bob | Cards: ['B3', 'B7'] scored 4
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['C3', 'C12', 'C1'] scored 0
# 07-Oct-21 10:49:33 - INFO - New Game.
# 07-Oct-21 10:49:33 - INFO - Player John | Cards: ['B12', 'C5', 'E4'] called real envido.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['E6', 'C11', 'C6'] folded.
# 07-Oct-21 10:49:34 - INFO - Hand finished.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['E6', 'C11', 'C6'] scored 0
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B12', 'C5', 'E4'] scored 2
# 07-Oct-21 10:49:34 - INFO - New Game.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['O10', 'E4', 'B11'] folded.
# 07-Oct-21 10:49:34 - INFO - Hand finished.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['O10', 'E4', 'B11'] scored 0
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B2', 'C3', 'C11'] scored 1
# 07-Oct-21 10:49:34 - INFO - New Game.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['E6', 'C10', 'E10'] called envido.
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B5', 'E7', 'B12'] called envido
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['E6', 'C10', 'E10'] folded.
# 07-Oct-21 10:49:34 - INFO - Hand finished.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['E6', 'C10', 'E10'] scored 0
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B5', 'E7', 'B12'] scored 3
# 07-Oct-21 10:49:34 - INFO - New Game.
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B10', 'E2', 'B6'] called real envido.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['O3', 'O1', 'B12'] folded.
# 07-Oct-21 10:49:34 - INFO - Hand finished.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['O3', 'O1', 'B12'] scored 0
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B10', 'E2', 'B6'] scored 2
# 07-Oct-21 10:49:34 - INFO - New Game.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['E3', 'E12', 'C4'] folded.
# 07-Oct-21 10:49:34 - INFO - Hand finished.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['E3', 'E12', 'C4'] scored 0
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['O12', 'E10', 'O2'] scored 1
# 07-Oct-21 10:49:34 - INFO - New Game.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['C1', 'B2', 'C12'] called real envido.
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B12', 'C7', 'B3'] called quiero envido
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['C1', 'B2', 'C12'] folded.
# 07-Oct-21 10:49:34 - INFO - Hand finished.
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['C1', 'B2', 'C12'] scored 0
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['B12', 'C7', 'B3'] scored 4
# 07-Oct-21 10:49:34 - INFO - New Game.
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['E4', 'O10'] played C4
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['B2', 'O11', 'C1'] called envido.
# 07-Oct-21 10:49:34 - INFO - Player John | Cards: ['E4', 'O10'] called no quiero envido
# 07-Oct-21 10:49:34 - INFO - Player Bob | Cards: ['B2', 'C1'] played O11
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['B2'] played C1
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O10'] played E4
# 07-Oct-21 10:49:35 - INFO - Hand finished.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['B2'] scored 2
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O10'] scored 0
# 07-Oct-21 10:49:35 - INFO - New Game.
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['B5', 'B7', 'E7'] called real envido.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O4', 'O3', 'E10'] called quiero envido
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['B5', 'E7'] played B7
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O4', 'O3', 'E10'] folded.
# 07-Oct-21 10:49:35 - INFO - Hand finished.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O4', 'O3', 'E10'] scored 0
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['B5', 'E7'] scored 4
# 07-Oct-21 10:49:35 - INFO - New Game.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['B1', 'E12'] played B11
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['C7', 'E10'] played B6
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['B1'] played E12
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['C7'] played E10
# 07-Oct-21 10:49:35 - INFO - Hand finished.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['B1'] scored 1
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['C7'] scored 0
# 07-Oct-21 10:49:35 - INFO - New Game.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O12', 'B2'] played B3
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O3', 'C1'] played C11
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O12', 'B2'] called truco to start truco
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O3', 'C1'] called quiero truco
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O12'] played B2
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O3', 'C1'] folded.
# 07-Oct-21 10:49:35 - INFO - Hand finished.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O12'] scored 2
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O3', 'C1'] scored 0
# 07-Oct-21 10:49:35 - INFO - New Game.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['C7', 'B3', 'C4'] folded.
# 07-Oct-21 10:49:35 - INFO - Hand finished.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['C7', 'B3', 'C4'] scored 0
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['C2', 'O12', 'E11'] scored 1
# 07-Oct-21 10:49:35 - INFO - New Game.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['C7', 'O11'] played B5
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['B7', 'O6'] played O10
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['B7', 'O6'] called truco to start truco
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['C7', 'O11'] called quiero truco
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O6'] played B7
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['C7'] played O11
# 07-Oct-21 10:49:35 - INFO - Hand finished.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['C7'] scored 0
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['O6'] scored 2
# 07-Oct-21 10:49:35 - INFO - New Game.
# 07-Oct-21 10:49:35 - INFO - Player John | Cards: ['B5', 'O7', 'B1'] called real envido.
# 07-Oct-21 10:49:35 - INFO - Player Bob | Cards: ['O4', 'C2', 'C4'] folded.
# 07-Oct-21 10:49:35 - INFO - Hand finished.
# 07-Oct-21 10:49:36 - INFO - Player Bob | Cards: ['O4', 'C2', 'C4'] scored 0
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['B5', 'O7', 'B1'] scored 2
# 07-Oct-21 10:49:36 - INFO - New Game.
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['C6', 'C11', 'O6'] called envido.
# 07-Oct-21 10:49:36 - INFO - Player Bob | Cards: ['O7', 'E2', 'E1'] folded.
# 07-Oct-21 10:49:36 - INFO - Hand finished.
# 07-Oct-21 10:49:36 - INFO - Player Bob | Cards: ['O7', 'E2', 'E1'] scored 0
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['C6', 'C11', 'O6'] scored 2
# 07-Oct-21 10:49:36 - INFO - New Game.
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['B1', 'E3'] played B3
# 07-Oct-21 10:49:36 - INFO - Player Bob | Cards: ['O12', 'O2', 'O6'] called truco to start truco
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['B1', 'E3'] folded.
# 07-Oct-21 10:49:36 - INFO - Hand finished.
# 07-Oct-21 10:49:36 - INFO - Player Bob | Cards: ['O12', 'O2', 'O6'] scored 1
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['B1', 'E3'] scored 0
# 07-Oct-21 10:49:36 - INFO - New Game.
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['B3', 'B6'] played B1
# 07-Oct-21 10:49:36 - INFO - Player Bob | Cards: ['C11', 'O12'] played E4
# 07-Oct-21 10:49:36 - INFO - Player John | Cards: ['B3'] played B6
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['C11'] played O12
# 07-Oct-21 10:49:37 - INFO - Hand finished.
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['C11'] scored 1
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['B3'] scored 0
# 07-Oct-21 10:49:37 - INFO - New Game.
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['E7', 'C11'] played B3
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E5', 'B7'] played C12
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C11'] played E7
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E5', 'B7'] called truco to start truco
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C11'] called no quiero truco
# 07-Oct-21 10:49:37 - INFO - Hand finished.
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E5', 'B7'] scored 1
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C11'] scored 0
# 07-Oct-21 10:49:37 - INFO - New Game.
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E11', 'O12', 'E3'] called real envido.
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C11', 'E10', 'O1'] called no quiero envido
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E11', 'E3'] played O12
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C11', 'E10', 'O1'] called truco to start truco
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E11', 'E3'] called quiero truco
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['E10', 'O1'] played C11
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E3'] played E11
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['O1'] played E10
# 07-Oct-21 10:49:37 - INFO - Hand finished.
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E3'] scored 3
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['O1'] scored 0
# 07-Oct-21 10:49:37 - INFO - New Game.
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E2', 'C5'] played E1
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['B10', 'C2', 'O4'] folded.
# 07-Oct-21 10:49:37 - INFO - Hand finished.
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E2', 'C5'] scored 1
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['B10', 'C2', 'O4'] scored 0
# 07-Oct-21 10:49:37 - INFO - New Game.
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C12', 'O2', 'O4'] called truco to start truco
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E1', 'B7', 'O7'] called quiero truco
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C12', 'O2', 'O4'] folded.
# 07-Oct-21 10:49:37 - INFO - Hand finished.
# 07-Oct-21 10:49:37 - INFO - Player Bob | Cards: ['E1', 'B7', 'O7'] scored 2
# 07-Oct-21 10:49:37 - INFO - Player John | Cards: ['C12', 'O2', 'O4'] scored 0
# 07-Oct-21 10:49:37 - INFO - New Game.
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['E12', 'O11', 'O2'] folded.
# 07-Oct-21 10:49:38 - INFO - Hand finished.
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['E12', 'O11', 'O2'] scored 0
# 07-Oct-21 10:49:38 - INFO - Player John | Cards: ['O3', 'C6', 'C2'] scored 1
# 07-Oct-21 10:49:38 - INFO - New Game.
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['O5', 'B11', 'B12'] called envido.
# 07-Oct-21 10:49:38 - INFO - Player John | Cards: ['C11', 'B10', 'E1'] called real envido
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['O5', 'B11', 'B12'] called quiero envido
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['B11', 'B12'] played O5
# 07-Oct-21 10:49:38 - INFO - Player John | Cards: ['C11', 'B10', 'E1'] folded.
# 07-Oct-21 10:49:38 - INFO - Hand finished.
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['B11', 'B12'] scored 6
# 07-Oct-21 10:49:38 - INFO - Player John | Cards: ['C11', 'B10', 'E1'] scored 0
# 07-Oct-21 10:49:38 - INFO - New Game.
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['E10', 'C1', 'O5'] called envido.
# 07-Oct-21 10:49:38 - INFO - Player John | Cards: ['B4', 'O4', 'O6'] called real envido
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['E10', 'C1', 'O5'] called quiero envido
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['E10', 'O5'] played C1
# 07-Oct-21 10:49:38 - INFO - Player John | Cards: ['B4', 'O4'] played O6
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['E10', 'O5'] folded.
# 07-Oct-21 10:49:38 - INFO - Hand finished.
# 07-Oct-21 10:49:38 - INFO - Player Bob | Cards: ['E10', 'O5'] scored 0
# 07-Oct-21 10:49:38 - INFO - Player John | Cards: ['B4', 'O4'] scored 6
# 07-Oct-21 10:49:38 - INFO - New Game.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ff5c6ecad328> in <module>
#      41
#      42             # Learn from replay buffer
# ---> 43             agent.learn()
#      44
#      45             # Logging
#
# ~\Desktop\Truco-RL\agent.py in learn(self)
#     245         self.optimizer.zero_grad()
#     246         loss.backward()
# --> 247         self.optimizer.step()
#     248
#     249         # Update Target Network
#
# c:\users\bautista\appdata\local\programs\python\python39\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# c:\users\bautista\appdata\local\programs\python\python39\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# c:\users\bautista\appdata\local\programs\python\python39\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     105                     state_steps.append(state['step'])
#     106
# --> 107             F.adam(params_with_grad,
#     108                    grads,
#     109                    exp_avgs,
#
# c:\users\bautista\appdata\local\programs\python\python39\lib\site-packages\torch\optim\_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      96         step_size = lr / bias_correction1
#      97
# ---> 98         param.addcdiv_(exp_avg, denom, value=-step_size)
#      99
#     100
#
# KeyboardInterrupt:

# %%
for agent in agents:
    save_agent(agent)
